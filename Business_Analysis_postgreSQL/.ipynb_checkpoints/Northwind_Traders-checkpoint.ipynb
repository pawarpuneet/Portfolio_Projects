# %% [markdown]
# # Northwind Traders Analysis
# Northwind database contains data on their customers, orders, products, suppliers, and other aspects of the business. The goals of this project are:
#
# - Evaluating employee performance to boost productivity
# - Understanding product sales and category performance to optimize inventory and marketing strategies
# - Analyzing sales growth to identify trends, monitor company progress, and make more accurate forecasts
# - And evaluating customer purchase behavior to target high-value customers with promotional incentives

# %% [markdown]
# ## Database Schema
#
# ![](schema_diagram.svg)

# %% [markdown]
# #### Before we can begin any analysis, we need to connect to the database and confirm the connection by making a SELECT query.

# %%
# Get username and password from the .env file
from dotenv import load_dotenv
import os

load_dotenv()  # Load environment variables from .env file

db_user = os.environ.get('PSQL_USER')
db_password = os.environ.get('PSQL_PASS')

# %%
# Load the sql extension and make a connection to the database
# %load_ext sql
# %sql postgresql://{db_user}:{db_password}@localhost:5432/northwind

# %%
# Run a select query to confirm connection to the database
# %sql SELECT * FROM customers LIMIT 5;
# Out:
#  * postgresql://postgres:***@localhost:5432/northwind
# 5 rows affected.
# [('ALFKI', 'Alfreds Futterkiste', 'Maria Anders', 'Sales Representative', 'Obere Str. 57', 'Berlin', None, '12209', 'Germany', '030-0074321', '030-0076545'),
#  ('ANATR', 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Owner', 'Avda. de la Constitución 2222', 'México D.F.', None, '05021', 'Mexico', '(5) 555-4729', '(5) 555-3745'),
#  ('ANTON', 'Antonio Moreno Taquería', 'Antonio Moreno', 'Owner', 'Mataderos  2312', 'México D.F.', None, '05023', 'Mexico', '(5) 555-3932', None),
#  ('AROUT', 'Around the Horn', 'Thomas Hardy', 'Sales Representative', '120 Hanover Sq.', 'London', None, 'WA1 1DP', 'UK', '(171) 555-7788', '(171) 555-6750'),
#  ('BERGS', 'Berglunds snabbköp', 'Christina Berglund', 'Order Administrator', 'Berguvsvägen  8', 'Luleå', None, 'S-958 22', 'Sweden', '0921-12 34 65', '0921-12 34 67')]

# %% [markdown]
# #### To obtain a list of all tables and views in the PostgreSQL database, we can query the information_schema.tables system table.

# %%
# %%sql
# SELECT table_name, table_type
#   FROM information_schema.tables
#  WHERE table_schema = 'public' AND table_type IN ('BASE TABLE', 'VIEW');
# Out:
#  * postgresql://postgres:***@localhost:5432/northwind
# 17 rows affected.
# [('territories', 'BASE TABLE'),
#  ('order_details', 'BASE TABLE'),
#  ('employee_territories', 'BASE TABLE'),
#  ('us_states', 'BASE TABLE'),
#  ('customers', 'BASE TABLE'),
#  ('orders', 'BASE TABLE'),
#  ('employees', 'BASE TABLE'),
#  ('shippers', 'BASE TABLE'),
#  ('products', 'BASE TABLE'),
#  ('categories', 'BASE TABLE'),
#  ('suppliers', 'BASE TABLE'),
#  ('region', 'BASE TABLE'),
#  ('customer_demographics', 'BASE TABLE'),
#  ('customer_customer_demo', 'BASE TABLE'),
#  ('orders_customers', 'VIEW'),
#  ('orders_products', 'VIEW'),
#  ('employees_orders', 'VIEW')]

# %% [markdown]
# #### Next, let's check the data types we have in the tables of interest for this analysis.

# %%
# %%sql
# SELECT DISTINCT data_type
#   FROM information_schema.columns
#  WHERE table_name IN ('categories', 'orders', 'employees', 'customers', 'order_details', 'products')
#  ORDER BY data_type
# Out:
#  * postgresql://postgres:***@localhost:5432/northwind
# 6 rows affected.
# [('character varying',),
#  ('date',),
#  ('integer',),
#  ('real',),
#  ('smallint',),
#  ('text',)]

# %% [markdown]
# #### Some columns have 'bytea' datatype which is used for storing raw binary data such as images, multimedia files or other non-textual data. Let's check which tables and columns have this datatype.

# %%
# %%sql
# SELECT table_name, column_name, data_type
#   FROM information_schema.columns
#  WHERE table_name IN ('categories', 'orders', 'employees', 'customers', 'order_details', 'products') AND data_type = 'bytea'
#  ORDER BY data_type
# Out:
#  * postgresql://postgres:***@localhost:5432/northwind
# 0 rows affected.
# []

# %% [markdown]
# #### We can see above that two columns are images and have bytea data type. This data type is challengin to render in Jupyter Notebooks and is also not needed for the analysis goals we have. So we can drop these columns.

# %%
# %%sql
# -- Drop the photo column from employees table
# ALTER TABLE employees
# DROP COLUMN photo;
# -- Drop the picture column from the categories table
# ALTER TABLE categories
# DROP COLUMN picture;
# Out:
#  * postgresql://postgres:***@localhost:5432/northwind
# (psycopg2.errors.UndefinedColumn) column "photo" of relation "employees" does not exist
#
# [SQL: -- Drop the photo column from employees table
# ALTER TABLE employees
# DROP COLUMN photo;]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %% [markdown]
# #### Confirm the 'bytea' data type is no longer present

# %%
# %%sql
# SELECT DISTINCT data_type
#   FROM information_schema.columns
#  WHERE table_name IN ('categories', 'orders', 'employees', 'customers', 'order_details', 'products')
#  ORDER BY data_type
# Out:
#  * postgresql://postgres:***@localhost:5432/northwind
# 6 rows affected.
# [('character varying',),
#  ('date',),
#  ('integer',),
#  ('real',),
#  ('smallint',),
#  ('text',)]

# %% [markdown]
# #### Let's create some VIEWs to streamline the rest of the project. We will need the following:
# - Combine orders and customers tables to get more detailed information about each order.
# - Combine order_details, products, and orders tables to get detailed order information, including the product name and quantity.
# - Combine employees and orders tables to see who is responsible for each order.

# %%
# %%sql
#
# DROP VIEW IF EXISTS orders_customers;
# DROP VIEW IF EXISTS orders_products;
# DROP VIEW IF EXISTS employees_orders;
#
# --Combine orders and customers tables to get more detailed information about each order.
#
# CREATE VIEW orders_customers AS
# SELECT o.order_id, o.order_date,
#        c.customer_id, c.company_name, c.contact_name
#   FROM orders o
#   JOIN customers c
#     ON o.customer_id = c.customer_id;
#
# --Combine order_details, products, and orders tables to get detailed order information, including the product name and quantity.
#
# CREATE VIEW orders_products AS
# SELECT od.order_id, od.unit_price, od.quantity, od.discount,
#        o.order_date,o.customer_id,
#        p.product_name, p.category_id, p.product_id
#   FROM order_details od
#   JOIN orders o
#     ON od.order_id = o.order_id
#   JOIN products p
#     ON od.product_id = p.product_id;
#
# --Combine employees and orders tables to see who is responsible for each order.
#
# CREATE VIEW employees_orders AS
# SELECT o.order_id, o.order_date,
#        e.first_name || ' ' || e.last_name AS employee_name, e.employee_id
#   FROM orders o
#   JOIN employees e
#     ON o.employee_id = e.employee_id;
# Out:
#  * postgresql://postgres:***@localhost:5432/northwind
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# []

# %% [markdown]
# ## Task 1: Ranking Employee Sales Performance
#  The objective is twofold:
# - First, the management team wants to recognize and reward top-performing employees, fostering a culture of excellence within the organization.
# - Second, they want to identify employees who might be struggling so that they can offer the necessary training or resources to help them improve.
#
# We can achieve this by ranking employees based on their total sales amount.

# %%
# %%sql
# --Calculate total sales for each employee
# WITH
# employee_sales AS (
# SELECT eo.employee_id, eo.employee_name,
#        ROUND(SUM((od.unit_price*od.quantity*(1-od.discount))::numeric),2) AS total_sales
#   FROM employees_orders eo
#   JOIN order_details od
#     ON eo.order_id = od.order_id
#  GROUP BY eo.employee_name, eo.employee_id
# )
# SELECT *,
#        RANK() OVER(ORDER BY total_sales DESC)
#   FROM employee_sales;
# Out:
#  * postgresql://postgres:***@localhost:5432/northwind
# 9 rows affected.
# [(4, 'Margaret Peacock', Decimal('232890.85'), 1),
#  (3, 'Janet Leverling', Decimal('202812.84'), 2),
#  (1, 'Nancy Davolio', Decimal('192107.60'), 3),
#  (2, 'Andrew Fuller', Decimal('166537.76'), 4),
#  (8, 'Laura Callahan', Decimal('126862.28'), 5),
#  (7, 'Robert King', Decimal('124568.23'), 6),
#  (9, 'Anne Dodsworth', Decimal('77308.07'), 7),
#  (6, 'Michael Suyama', Decimal('73913.13'), 8),
#  (5, 'Steven Buchanan', Decimal('68792.28'), 9)]

# %% [markdown]
# #### The above table gives us the employee ranking by sales performance.

# %% [markdown]
# ## Task 2: Running Total of Monthly Sales
# The objective is to visualize the progress of the sales and identify trends that might shape the company's future strategies.
#
# For this we need to visualize the company's sales progress over time on a monthly basis. This will involve aggregating the sales data at a monthly level and calculating a running total of sales by month.

# %%
# %%sql
# WITH
# monthly AS(
# SELECT DATE(DATE_TRUNC('month', order_date)) as order_month,
#        ROUND(SUM((unit_price*quantity*(1-discount))::numeric),2) AS monthly_sales
#   FROM orders_products
#  GROUP BY DATE_TRUNC('month', order_date)
#  ORDER BY order_month
# )
# SELECT *,
#        SUM(monthly_sales) OVER(ROWS BETWEEN UNBOUNDED PRECEDING AND CURRENT ROW) AS running_total
#   FROM monthly;
# Out:
#  * postgresql://postgres:***@localhost:5432/northwind
# 23 rows affected.
# [(datetime.date(1996, 7, 1), Decimal('27861.90'), Decimal('27861.90')),
#  (datetime.date(1996, 8, 1), Decimal('25485.28'), Decimal('53347.18')),
#  (datetime.date(1996, 9, 1), Decimal('26381.40'), Decimal('79728.58')),
#  (datetime.date(1996, 10, 1), Decimal('37515.72'), Decimal('117244.30')),
#  (datetime.date(1996, 11, 1), Decimal('45600.05'), Decimal('162844.35')),
#  (datetime.date(1996, 12, 1), Decimal('45239.63'), Decimal('208083.98')),
#  (datetime.date(1997, 1, 1), Decimal('61258.07'), Decimal('269342.05')),
#  (datetime.date(1997, 2, 1), Decimal('38483.63'), Decimal('307825.68')),
#  (datetime.date(1997, 3, 1), Decimal('38547.22'), Decimal('346372.90')),
#  (datetime.date(1997, 4, 1), Decimal('53032.95'), Decimal('399405.85')),
#  (datetime.date(1997, 5, 1), Decimal('53781.29'), Decimal('453187.14')),
#  (datetime.date(1997, 6, 1), Decimal('36362.80'), Decimal('489549.94')),
#  (datetime.date(1997, 7, 1), Decimal('51020.86'), Decimal('540570.80')),
#  (datetime.date(1997, 8, 1), Decimal('47287.67'), Decimal('587858.47')),
#  (datetime.date(1997, 9, 1), Decimal('55629.24'), Decimal('643487.71')),
#  (datetime.date(1997, 10, 1), Decimal('66749.23'), Decimal('710236.94')),
#  (datetime.date(1997, 11, 1), Decimal('43533.81'), Decimal('753770.75')),
#  (datetime.date(1997, 12, 1), Decimal('71398.43'), Decimal('825169.18')),
#  (datetime.date(1998, 1, 1), Decimal('94222.11'), Decimal('919391.29')),
#  (datetime.date(1998, 2, 1), Decimal('99415.29'), Decimal('1018806.58')),
#  (datetime.date(1998, 3, 1), Decimal('104854.16'), Decimal('1123660.74')),
#  (datetime.date(1998, 4, 1), Decimal('123798.68'), Decimal('1247459.42')),
#  (datetime.date(1998, 5, 1), Decimal('18333.63'), Decimal('1265793.05'))]

# %% [markdown]
# ## Task 3: Month-Over-Month Sales Growth
# Understanding the rate at which sales are increasing or decreasing from month to month will help identify significant trends.
#
# For this task we will need to calculate the percentage change in sales from one month to the next.

# %%
# %%sql
# WITH
# monthly AS(
# SELECT DATE(DATE_TRUNC('month', order_date)) as order_month,
#        ROUND(SUM((unit_price*quantity*(1-discount))::numeric),2) AS monthly_sales
#   FROM orders_products
#  GROUP BY DATE_TRUNC('month', order_date)
# ),
# month_over_month AS(
# SELECT *,
#        LAG(monthly_sales) OVER(ORDER BY order_month) AS previous_month_sales
#   FROM monthly
# )
# SELECT *,
#        ROUND((monthly_sales - previous_month_sales)/previous_month_sales * 100,2) AS growth_percentage
#   FROM month_over_month;
# Out:
#  * postgresql://postgres:***@localhost:5432/northwind
# 23 rows affected.
# [(datetime.date(1996, 7, 1), Decimal('27861.90'), None, None),
#  (datetime.date(1996, 8, 1), Decimal('25485.28'), Decimal('27861.90'), Decimal('-8.53')),
#  (datetime.date(1996, 9, 1), Decimal('26381.40'), Decimal('25485.28'), Decimal('3.52')),
#  (datetime.date(1996, 10, 1), Decimal('37515.72'), Decimal('26381.40'), Decimal('42.21')),
#  (datetime.date(1996, 11, 1), Decimal('45600.05'), Decimal('37515.72'), Decimal('21.55')),
#  (datetime.date(1996, 12, 1), Decimal('45239.63'), Decimal('45600.05'), Decimal('-0.79')),
#  (datetime.date(1997, 1, 1), Decimal('61258.07'), Decimal('45239.63'), Decimal('35.41')),
#  (datetime.date(1997, 2, 1), Decimal('38483.63'), Decimal('61258.07'), Decimal('-37.18')),
#  (datetime.date(1997, 3, 1), Decimal('38547.22'), Decimal('38483.63'), Decimal('0.17')),
#  (datetime.date(1997, 4, 1), Decimal('53032.95'), Decimal('38547.22'), Decimal('37.58')),
#  (datetime.date(1997, 5, 1), Decimal('53781.29'), Decimal('53032.95'), Decimal('1.41')),
#  (datetime.date(1997, 6, 1), Decimal('36362.80'), Decimal('53781.29'), Decimal('-32.39')),
#  (datetime.date(1997, 7, 1), Decimal('51020.86'), Decimal('36362.80'), Decimal('40.31')),
#  (datetime.date(1997, 8, 1), Decimal('47287.67'), Decimal('51020.86'), Decimal('-7.32')),
#  (datetime.date(1997, 9, 1), Decimal('55629.24'), Decimal('47287.67'), Decimal('17.64')),
#  (datetime.date(1997, 10, 1), Decimal('66749.23'), Decimal('55629.24'), Decimal('19.99')),
#  (datetime.date(1997, 11, 1), Decimal('43533.81'), Decimal('66749.23'), Decimal('-34.78')),
#  (datetime.date(1997, 12, 1), Decimal('71398.43'), Decimal('43533.81'), Decimal('64.01')),
#  (datetime.date(1998, 1, 1), Decimal('94222.11'), Decimal('71398.43'), Decimal('31.97')),
#  (datetime.date(1998, 2, 1), Decimal('99415.29'), Decimal('94222.11'), Decimal('5.51')),
#  (datetime.date(1998, 3, 1), Decimal('104854.16'), Decimal('99415.29'), Decimal('5.47')),
#  (datetime.date(1998, 4, 1), Decimal('123798.68'), Decimal('104854.16'), Decimal('18.07')),
#  (datetime.date(1998, 5, 1), Decimal('18333.63'), Decimal('123798.68'), Decimal('-85.19'))]

# %% [markdown]
# ## Task 4: Identifying High-Value Customers
# Objective is to identify high-value customers to whom company can offer targeted promotions and special offers, which could drive increased sales, improve customer retention, and attract new customers.
#
# We can do this by identifying customers with above-average order values. These customers might be businesses buying in bulk or individuals purchasing high-end products. We will catergorize each order as 'Above Average' or 'Average/Below Average' and then count how many orders are 'Above Average' for each customer.

# %%
# %%sql
# WITH
# order_value AS(
# SELECT oc.order_id, oc.company_name, oc.contact_name,
#        ROUND(SUM((od.unit_price*od.quantity*(1-od.discount))::numeric),2) AS order_value
#   FROM orders_customers oc
#   JOIN order_details od
#     ON oc.order_id = od.order_id
#  GROUP BY oc.order_id, oc.company_name, oc.contact_name
# )
# SELECT *,
#        --AVG(order_value) OVER() AS avg_order_value,
#        CASE
#        WHEN order_value > (AVG(order_value) OVER() ) THEN 'Above Average'
#        ELSE 'Average/Below Average'
#        END AS order_category
#   FROM order_value
#  LIMIT 10;
# Out:
#  * postgresql://postgres:***@localhost:5432/northwind
# 10 rows affected.
# [(10248, 'Vins et alcools Chevalier', 'Paul Henriot', Decimal('440.00'), 'Average/Below Average'),
#  (10249, 'Toms Spezialitäten', 'Karin Josephs', Decimal('1863.40'), 'Above Average'),
#  (10250, 'Hanari Carnes', 'Mario Pontes', Decimal('1552.60'), 'Above Average'),
#  (10251, 'Victuailles en stock', 'Mary Saveley', Decimal('654.06'), 'Average/Below Average'),
#  (10252, 'Suprêmes délices', 'Pascale Cartrain', Decimal('3597.90'), 'Above Average'),
#  (10253, 'Hanari Carnes', 'Mario Pontes', Decimal('1444.80'), 'Average/Below Average'),
#  (10254, 'Chop-suey Chinese', 'Yang Wang', Decimal('556.62'), 'Average/Below Average'),
#  (10255, 'Richter Supermarkt', 'Michael Holz', Decimal('2490.50'), 'Above Average'),
#  (10256, 'Wellington Importadora', 'Paula Parente', Decimal('517.80'), 'Average/Below Average'),
#  (10257, 'HILARION-Abastos', 'Carlos Hernández', Decimal('1119.90'), 'Average/Below Average')]

# %% [markdown]
# #### We have categorized each order as ‘Above Average’ or ‘Average/Below Average’ in the table above. Now let's find out how many orders are ‘Above Average’ for each customer.

# %%
# %%sql
# WITH
# order_value AS(
# SELECT oc.order_id, oc.customer_id, oc.company_name, oc.contact_name,
#        ROUND(SUM((od.unit_price*od.quantity*(1-od.discount))::numeric),2) AS order_value
#   FROM orders_customers oc
#   JOIN order_details od
#     ON oc.order_id = od.order_id
#  GROUP BY oc.order_id, oc.customer_id, oc.company_name, oc.contact_name
# ),
# order_cat AS(
# SELECT *,
#        --AVG(order_value) OVER() AS avg_order_value,
#        CASE
#        WHEN order_value > (AVG(order_value) OVER() ) THEN 'Above Average'
#        ELSE 'Average/Below Average'
#        END AS order_category
#   FROM order_value
# )
# SELECT customer_id, company_name, contact_name, COUNT(*) AS num_above_avg_orders
#   FROM order_cat
#  WHERE order_category = 'Above Average'
#  GROUP BY customer_id, company_name, contact_name
#  ORDER BY num_above_avg_orders DESC
# Out:
#  * postgresql://postgres:***@localhost:5432/northwind
# 64 rows affected.
# [('ERNSH', 'Ernst Handel', 'Roland Mendel', 26),
#  ('SAVEA', 'Save-a-lot Markets', 'Jose Pavarotti', 26),
#  ('QUICK', 'QUICK-Stop', 'Horst Kloss', 22),
#  ('HUNGO', 'Hungry Owl All-Night Grocers', 'Patricia McKenna', 11),
#  ('RATTC', 'Rattlesnake Canyon Grocery', 'Paula Wilson', 10),
#  ('BONAP', "Bon app'", 'Laurence Lebihan', 8),
#  ('FOLKO', 'Folk och fä HB', 'Maria Larsson', 8),
#  ('FRANK', 'Frankenversand', 'Peter Franken', 7),
#  ('RICSU', 'Richter Supermarkt', 'Michael Holz', 7),
#  ('HILAA', 'HILARION-Abastos', 'Carlos Hernández', 7),
#  ('SUPRD', 'Suprêmes délices', 'Pascale Cartrain', 6),
#  ('MEREP', 'Mère Paillarde', 'Jean Fresnière', 6),
#  ('LINOD', 'LINO-Delicateses', 'Felipe Izquierdo', 6),
#  ('LEHMS', 'Lehmanns Marktstand', 'Renate Messner', 6),
#  ('KOENE', 'Königlich Essen', 'Philip Cramer', 6),
#  ('QUEEN', 'Queen Cozinha', 'Lúcia Carvalho', 6),
#  ('SEVES', 'Seven Seas Imports', 'Hari Kumar', 5),
#  ('HANAR', 'Hanari Carnes', 'Mario Pontes', 5),
#  ('BERGS', 'Berglunds snabbköp', 'Christina Berglund', 5),
#  ('VAFFE', 'Vaffeljernet', 'Palle Ibsen', 5),
#  ('WHITC', 'White Clover Markets', 'Karl Jablonski', 5),
#  ('WARTH', 'Wartian Herkku', 'Pirkko Koskitalo', 4),
#  ('BOTTM', 'Bottom-Dollar Markets', 'Elizabeth Lincoln', 4),
#  ('CHOPS', 'Chop-suey Chinese', 'Yang Wang', 4),
#  ('LILAS', 'LILA-Supermercado', 'Carlos González', 4),
#  ('BLONP', 'Blondesddsl père et fils', 'Frédérique Citeaux', 4),
#  ('EASTC', 'Eastern Connection', 'Ann Devon', 4),
#  ('OLDWO', 'Old World Delicatessen', 'Rene Phillips', 4),
#  ('PICCO', 'Piccolo und mehr', 'Georg Pipps', 4),
#  ('VICTE', 'Victuailles en stock', 'Mary Saveley', 3),
#  ('GODOS', 'Godos Cocina Típica', 'José Pedro Freyre', 3),
#  ('FOLIG', 'Folies gourmandes', 'Martine Rancé', 3),
#  ('SPLIR', 'Split Rail Beer & Ale', 'Art Braunschweiger', 3),
#  ('AROUT', 'Around the Horn', 'Thomas Hardy', 3),
#  ('OTTIK', 'Ottilies Käseladen', 'Henriette Pfalzheim', 3),
#  ('RICAR', 'Ricardo Adocicados', 'Janete Limeira', 3),
#  ('WANDK', 'Die Wandernde Kuh', 'Rita Müller', 2),
#  ('SIMOB', 'Simons bistro', 'Jytte Petersen', 2),
#  ('LAMAI', "La maison d'Asie", 'Annette Roulet', 2),
#  ('GREAL', 'Great Lakes Food Market', 'Howard Snyder', 2),
#  ('REGGC', 'Reggiani Caseifici', 'Maurizio Moroni', 2),
#  ('MAISD', 'Maison Dewey', 'Catherine Dewey', 2),
#  ('FURIB', 'Furia Bacalhau e Frutos do Mar', 'Lino Rodriguez', 2),
#  ('ANTON', 'Antonio Moreno Taquería', 'Antonio Moreno', 2),
#  ('TOMSP', 'Toms Spezialitäten', 'Karin Josephs', 1),
#  ('BOLID', 'Bólido Comidas preparadas', 'Martín Sommer', 1),
#  ('COMMI', 'Comércio Mineiro', 'Pedro Afonso', 1),
#  ('DRACD', 'Drachenblut Delikatessen', 'Sven Ottlieb', 1),
#  ('FAMIA', 'Familia Arquibaldo', 'Aria Cruz', 1),
#  ('FRANR', 'France restauration', 'Carine Schmitt', 1),
#  ('GOURL', 'Gourmet Lanchonetes', 'André Fonseca', 1),
#  ('HUNGC', 'Hungry Coyote Import Store', 'Yoshi Latimer', 1),
#  ('ISLAT', 'Island Trading', 'Helen Bennett', 1),
#  ('LONEP', 'Lonesome Pine Restaurant', 'Fran Wilson', 1),
#  ('MAGAA', 'Magazzini Alimentari Riuniti', 'Giovanni Rovelli', 1),
#  ('MORGK', 'Morgenstern Gesundkost', 'Alexander Feuer', 1),
#  ('OCEAN', 'Océano Atlántico Ltda.', 'Yvonne Moncada', 1),
#  ('PRINI', 'Princesa Isabel Vinhos', 'Isabel de Castro', 1),
#  ('SANTG', 'Santé Gourmet', 'Jonas Bergulfsen', 1),
#  ('SPECD', 'Spécialités du monde', 'Dominique Perrier', 1),
#  ('THEBI', 'The Big Cheese', 'Liz Nixon', 1),
#  ('TORTU', 'Tortuga Restaurante', 'Miguel Angel Paolino', 1),
#  ('TRADH', 'Tradição Hipermercados', 'Anabela Domingues', 1),
#  ('WELLI', 'Wellington Importadora', 'Paula Parente', 1)]

# %% [markdown]
# #### Table above gives us the on high-value customers.

# %% [markdown]
# ## Task 5: Percentage of Sales for Each Category
# By knowing the percentage of total sales for each product category, company can gain insights into which categories drive most of the company's sales. This understanding will help guide decisions about inventory (e.g., which categories should be stocked more heavily) and marketing strategies (e.g., which categories should be promoted more aggressively).

# %%
# %%sql
# WITH
# cat_sale AS(
# SELECT category_id,
#        ROUND(SUM((unit_price*quantity*(1-discount))::numeric),2) AS sales
#   FROM orders_products
#  GROUP BY category_id
# ),
# cat_sale_name AS(
# SELECT cs.category_id,
#        c.category_name,
#        cs.sales
#   FROM cat_sale cs
#   JOIN categories c
#     ON cs.category_id = c.category_id
# )
# SELECT *,
#        ROUND(sales/(SUM(sales) OVER()) * 100::numeric,2) AS percent_of_total_sales
#   FROM cat_sale_name
#  ORDER BY percent_of_total_sales DESC
# Out:
#  * postgresql://postgres:***@localhost:5432/northwind
# 8 rows affected.
# [(1, 'Beverages', Decimal('267868.18'), Decimal('21.16')),
#  (4, 'Dairy Products', Decimal('234507.28'), Decimal('18.53')),
#  (3, 'Confections', Decimal('167357.23'), Decimal('13.22')),
#  (6, 'Meat/Poultry', Decimal('163022.36'), Decimal('12.88')),
#  (8, 'Seafood', Decimal('131261.74'), Decimal('10.37')),
#  (2, 'Condiments', Decimal('106047.08'), Decimal('8.38')),
#  (7, 'Produce', Decimal('99984.58'), Decimal('7.90')),
#  (5, 'Grains/Cereals', Decimal('95744.59'), Decimal('7.56'))]

# %% [markdown]
# #### Above table shows us that Beverages is the top category followed by Dairy Products. Produce and Grains/Cereals are the categories with the smallest sales percentage

# %% [markdown]
# ## Task 6: Top Products Per Category
# Company needs to know the top three items sold in each product category. This will allow them to identify star performers and ensure that these products are kept in stock and marketed prominently.

# %%
# %%sql
# WITH
# cat_sale AS(
# SELECT category_id, product_id, product_name,
#        ROUND(SUM((unit_price*quantity*(1-discount))::numeric),2) AS sales
#   FROM orders_products
#  GROUP BY category_id, product_id, product_name
# ),
# cat_sale_name AS(
# SELECT cs.category_id,
#        c.category_name,
#        cs.product_id,
#        cs.product_name,
#        cs.sales
#   FROM cat_sale cs
#   JOIN categories c
#     ON cs.category_id = c.category_id
#  ORDER BY cs.category_id
# ),
# sales_rank AS(
# SELECT *,
#        RANK() OVER(PARTITION BY category_id
#                         ORDER BY SALES DESC) AS sales_ranking
#   FROM cat_sale_name
# )
# SELECT *
#   FROM sales_rank
#  WHERE sales_ranking <= 3
# Out:
#  * postgresql://postgres:***@localhost:5432/northwind
# 24 rows affected.
# [(1, 'Beverages', 38, 'Côte de Blaye', Decimal('141396.74'), 1),
#  (1, 'Beverages', 43, 'Ipoh Coffee', Decimal('23526.70'), 2),
#  (1, 'Beverages', 2, 'Chang', Decimal('16355.96'), 3),
#  (2, 'Condiments', 63, 'Vegie-spread', Decimal('16701.10'), 1),
#  (2, 'Condiments', 61, "Sirop d'érable", Decimal('14352.60'), 2),
#  (2, 'Condiments', 65, 'Louisiana Fiery Hot Pepper Sauce', Decimal('13869.89'), 3),
#  (3, 'Confections', 62, 'Tarte au sucre', Decimal('47234.97'), 1),
#  (3, 'Confections', 20, "Sir Rodney's Marmalade", Decimal('22563.36'), 2),
#  (3, 'Confections', 26, 'Gumbär Gummibärchen', Decimal('19849.14'), 3),
#  (4, 'Dairy Products', 59, 'Raclette Courdavault', Decimal('71155.70'), 1),
#  (4, 'Dairy Products', 60, 'Camembert Pierrot', Decimal('46825.48'), 2),
#  (4, 'Dairy Products', 72, 'Mozzarella di Giovanni', Decimal('24900.13'), 3),
#  (5, 'Grains/Cereals', 56, 'Gnocchi di nonna Alice', Decimal('42593.06'), 1),
#  (5, 'Grains/Cereals', 64, 'Wimmers gute Semmelknödel', Decimal('21957.97'), 2),
#  (5, 'Grains/Cereals', 42, 'Singaporean Hokkien Fried Mee', Decimal('8575.00'), 3),
#  (6, 'Meat/Poultry', 29, 'Thüringer Rostbratwurst', Decimal('80368.67'), 1),
#  (6, 'Meat/Poultry', 17, 'Alice Mutton', Decimal('32698.38'), 2),
#  (6, 'Meat/Poultry', 53, 'Perth Pasties', Decimal('20574.17'), 3),
#  (7, 'Produce', 51, 'Manjimup Dried Apples', Decimal('41819.65'), 1),
#  (7, 'Produce', 28, 'Rössle Sauerkraut', Decimal('25696.64'), 2),
#  (7, 'Produce', 7, "Uncle Bob's Organic Dried Pears", Decimal('22044.30'), 3),
#  (8, 'Seafood', 18, 'Carnarvon Tigers', Decimal('29171.87'), 1),
#  (8, 'Seafood', 10, 'Ikura', Decimal('20867.34'), 2),
#  (8, 'Seafood', 40, 'Boston Crab Meat', Decimal('17910.63'), 3)]

# %% [markdown]
# #### Table above gives us the top 3 products sold from each category.

# %% [markdown]
# # Conclusion:
# We have completed all 6 tasks:
# 1. Ranked Employee Sales Performance based on their total sales amount.
# 2. Calculated Running Total of Monthly Sales.
# 3. Calculated Month-Over-Month Sales Growth.
# 4. Identified High-Value Customers using above-average order values.
# 5. Calculated Percentage of Sales for Each Category.
# 6. Identified Top 3 Products Per Category.

# %% [markdown]
# # Author
# ### Puneet Pawar
